# %%
# %run "../Includes/Configuration"

# %%
# %run "../Includes/Common_Functions"

# %%
# %run "../Includes/sas alternative"

# %%
df_raw = spark.read.csv('abfss://udayadbcontainerv1@udayadbsav1.dfs.core.windows.net/Project-2/Raw-V1/races.csv',header=True,inferSchema=True)

# %%
df_raw.display()

# %%
df_processed = spark.read.parquet("abfss://udayadbcontainerv1@udayadbsav1.dfs.core.windows.net/Project-2/Processed-V1/races")

# %%
df_processed.display()

# %%
df_presentation = spark.read.parquet("abfss://udayadbcontainerv1@udayadbsav1.dfs.core.windows.net/Project-2/Presentation-V1/Race_Results_R_R")

# %%
df_presentation.display()

# %%
server_name = 'uday-adb-as-v5.sql.azuresynapse.net'
db_name = 'udayadbDSPv1'

# %%
synapse_jdbc_url ="""
jdbc:sqlserver://uday-adb-as-v5.sql.azuresynapse.net:1433;
database=db_name;
user=sqladminuser@uday-adb-as-v5;
password=Memory77;
encrypt=true;
trustServerCertificate=false;
hostNameInCertificate=*.sql.azuresynapse.net;
loginTimeout=30;"""
